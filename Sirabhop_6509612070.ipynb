# %% [markdown]
# #Problem framing

# %% [markdown]
# to understand how much renewable energy being used compare to nonrenewale energy

# %% [markdown]
# #Data collection

# %% [markdown]
# From :https://www.kaggle.com/datasets/jamesvandenberg/renewable-power-generation/

# %% [markdown]
# Aboat: energy consumption and renewable energy generation

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_continent = pd.read_csv('/content/drive/MyDrive/Data/Continent_Consumption_TWH.csv')
data_continent
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
data_renew = pd.read_csv('/content/drive/MyDrive/Data/renewablePowerGeneration97-17.csv')
data_renew
# Out:
#     Year  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)
# 0   1990     2191.67          3.88            0.09             36.42
# 1   1991     2268.63          4.19            0.10             37.39
# 2   1992     2267.16          4.63            0.12             39.30
# 3   1993     2397.67          5.61            0.15             40.23
# 4   1994     2419.73          7.31            0.17             41.05
# 5   1995     2545.96          7.95            0.19             39.89
# 6   1996     2583.18          9.45            0.22             42.18
# 7   1997     2614.54         12.08            0.27             42.38
# 8   1998     2628.63         16.07            0.35             45.35
# 9   1999     2636.26         21.52            0.61             48.66
# 10  2000     2695.85         31.34            0.99             51.98
# 11  2001     2638.20         38.45            1.32             51.57
# 12  2002     2711.12         52.85            1.58             52.29
# ...

# %% [markdown]
# #Data preparation

# %% [markdown]
# check for duplicate

# %%
data_continent.duplicated().sum()
# Out:
# 0

# %%
data_renew.duplicated().sum()
# Out:
# 0

# %% [markdown]
# check for null

# %%
data_continent.isna().sum()
# Out:
# Year                  0
# World(TWh)            0
# OECD(TWh)             0
# BRICS(TWh)            0
# Europe(TWh)           0
# North America(TWh)    0
# Latin America(TWh)    0
# Asia(TWh)             0
# Pacific(TWh)          0
# Africa(TWh)           0
# Middle-East(TWh)      0
# CIS(TWh)              0
# dtype: int64

# %%
data_renew.isna().sum()
# Out:
# Year                0
# Hydro(TWh)          0
# Biofuel(TWh)        0
# Solar PV (TWh)      0
# Geothermal (TWh)    0
# dtype: int64

# %% [markdown]
# check for inconsistent datatypes

# %%
data_renew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              28 non-null     int64
#  1   Hydro(TWh)        28 non-null     float64
#  2   Biofuel(TWh)      28 non-null     float64
#  3   Solar PV (TWh)    28 non-null     float64
#  4   Geothermal (TWh)  28 non-null     float64
#  5   world(TWh)        28 non-null     float64
#  6   World(TWh)        28 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.7 KB

# %%
data_continent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           31 non-null     int64
#  1   World          31 non-null     float64
#  2   OECD           31 non-null     float64
#  3   BRICS          31 non-null     float64
#  4   Europe         31 non-null     float64
#  5   North America  31 non-null     float64
#  6   Latin America  31 non-null     float64
#  7   Asia           31 non-null     float64
#  8   Pacific        31 non-null     float64
#  9   Africa         31 non-null     float64
#  10  Middle-East    31 non-null     float64
#  11  CIS            31 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 3.0 KB

# %% [markdown]
# unit=terawatt hours (TWh)

# %%
data_continent.columns
# Out:
# Index(['Year', 'World', 'OECD', 'BRICS', 'Europe', 'North America',
#        'Latin America', 'Asia', 'Pacific', 'Africa', 'Middle-East', 'CIS'],
#       dtype='object')

# %%
data_continent.columns=['Year', 'World(TWh)', 'OECD(TWh)', 'BRICS(TWh)', 'Europe(TWh)', 'North America(TWh)',
       'Latin America(TWh)', 'Asia(TWh)', 'Pacific(TWh)', 'Africa(TWh)', 'Middle-East(TWh)', 'CIS(TWh)']

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# plotting graph to visualize the number for easy comparison

# %%
data_continent.plot(x='Year')
# Out:
# <Axes: xlabel='Year'>

# %%
data_renew.plot(x='Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# for easier way to compare

# %%
dat=data_continent["World(TWh)"]
dat
# Out:
# 0     101855.54
# 1     102483.56
# 2     102588.23
# 3     103646.56
# 4     104449.03
# 5     107112.30
# 6     109763.94
# 7     110903.68
# 8     111450.29
# 9     113974.00
# 10    116590.75
# 11    117521.15
# 12    120207.68
# 13    124464.26
# 14    129953.62
# 15    133582.18
# 16    137396.82
# 17    141211.46
# 18    142874.55
# 19    141490.58
# 20    149294.31
# 21    151783.13
# 22    153748.60
# 23    155958.30
# 24    157667.91
# 25    158086.59
# 26    159377.52
# 27    162459.47
# 28    166297.37
# 29    167553.41
# 30    160819.64
# Name: World(TWh), dtype: float64

# %%
data_renew.insert(5,"world(TWh)",dat)

# %%
data_renew.plot(x='Year')
# Out:
# <Axes: xlabel='Year'>
